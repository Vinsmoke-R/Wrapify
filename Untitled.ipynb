# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spotipy
#   Downloading spotipy-2.25.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-7.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from spotipy) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.25.0->spotipy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.25.0->spotipy) (2025.4.26)
# Downloading spotipy-2.25.1-py3-none-any.whl (31 kB)
# Downloading redis-7.1.0-py3-none-any.whl (354 kB)
# Installing collected packages: redis, spotipy
#
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    -------------------- ------------------- 1/2 [spotipy]
#    -------------------- ------------------- 1/2 [spotipy]
#    -------------------- ------------------- 1/2 [spotipy]
#    ---------------------------------------- 2/2 [spotipy]
#
# Successfully installed redis-7.1.0 spotipy-2.25.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests 
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import time 
import datetime

# %%
CLIENT_ID = "client_id"
CLIENT_SECRET = "client_secret"
SPOTIFY_URL = "http://127.0.0.1:8000/callback"
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                               client_secret=CLIENT_SECRET,
                                               redirect_uri=SPOTIFY_URL,
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10, offset=0, time_range = 'short_term')

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#       'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S',
#       'id': '4G9NDjRyZFDlJKMRL8hx3S',
#       'name': 'sombr',
#       'type': 'artist',
#       'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7mvXPtV4jvA1hp5Wx2FAJA'},
#     'href': 'https://api.spotify.com/v1/albums/7mvXPtV4jvA1hp5Wx2FAJA',
#     'id': '7mvXPtV4jvA1hp5Wx2FAJA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2eb391e0b3c3bc21c127db6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2eb391e0b3c3bc21c127db6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2eb391e0b3c3bc21c127db6',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'I Barely Know Her',
#     'release_date': '2025-08-22',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7mvXPtV4jvA1hp5Wx2FAJA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#      'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S',
#      'id': '4G9NDjRyZFDlJKMRL8hx3S',
#      'name': 'sombr',
#      'type': 'artist',
#      'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 199032,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB12405502'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7qjZnBKE73H4Oxkopwulqe'},
#    'href': 'https://api.spotify.com/v1/tracks/7qjZnBKE73H4Oxkopwulqe',
#    'id': '7qjZnBKE73H4Oxkopwulqe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'back to friends',
#    'popularity': 92,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7qjZnBKE73H4Oxkopwulqe'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gdMJYnopf2nEUcanAwstx'},
#       'href': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx',
#       'id': '4gdMJYnopf2nEUcanAwstx',
#       'name': 'Anuv Jain',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gdMJYnopf2nEUcanAwstx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2LeZ6oWQed5ewVUpyGJKDh'},
#     'href': 'https://api.spotify.com/v1/albums/2LeZ6oWQed5ewVUpyGJKDh',
#     'id': '2LeZ6oWQed5ewVUpyGJKDh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d8ca783fa570b57e082f4374',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d8ca783fa570b57e082f4374',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d8ca783fa570b57e082f4374',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Baarishein',
#     'release_date': '2018-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2LeZ6oWQed5ewVUpyGJKDh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gdMJYnopf2nEUcanAwstx'},
#      'href': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx',
#      'id': '4gdMJYnopf2nEUcanAwstx',
#      'name': 'Anuv Jain',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gdMJYnopf2nEUcanAwstx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 207312,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADK1712757'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3WLJ7D5kh44K5eJ1NqZQ6W'},
#    'href': 'https://api.spotify.com/v1/tracks/3WLJ7D5kh44K5eJ1NqZQ6W',
#    'id': '3WLJ7D5kh44K5eJ1NqZQ6W',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Baarishein',
#    'popularity': 76,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3WLJ7D5kh44K5eJ1NqZQ6W'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#       'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#       'id': '1wRPtKGflJrBx9BmLsSwlU',
#       'name': 'Pritam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CtqkIRtoYPHgFc1ft1DPi'},
#     'href': 'https://api.spotify.com/v1/albums/6CtqkIRtoYPHgFc1ft1DPi',
#     'id': '6CtqkIRtoYPHgFc1ft1DPi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27371da5e89467bd75d2ed9f1fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0271da5e89467bd75d2ed9f1fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485171da5e89467bd75d2ed9f1fa',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Jannat 2 (Original Motion Picture Soundtrack)',
#     'release_date': '2012-03-30',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6CtqkIRtoYPHgFc1ft1DPi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#      'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#      'id': '1wRPtKGflJrBx9BmLsSwlU',
#      'name': 'Pritam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5SuRAj1A9FEHj5NxS86YAm'},
#      'href': 'https://api.spotify.com/v1/artists/5SuRAj1A9FEHj5NxS86YAm',
#      'id': '5SuRAj1A9FEHj5NxS86YAm',
#      'name': 'Shafqat Amanat Ali',
#      'type': 'artist',
#      'uri': 'spotify:artist:5SuRAj1A9FEHj5NxS86YAm'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 272973,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS171200195'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1CVqr5LImdmJ1Upt4z08Pm'},
#    'href': 'https://api.spotify.com/v1/tracks/1CVqr5LImdmJ1Upt4z08Pm',
#    'id': '1CVqr5LImdmJ1Upt4z08Pm',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tu Hi Mera',
#    'popularity': 74,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1CVqr5LImdmJ1Upt4z08Pm'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Op1QmEE3Eye8gdNrla3ok'},
#       'href': 'https://api.spotify.com/v1/artists/5Op1QmEE3Eye8gdNrla3ok',
#       'id': '5Op1QmEE3Eye8gdNrla3ok',
#       'name': 'Rap Demon',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Op1QmEE3Eye8gdNrla3ok'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/69xcFpmqTOmFNOL08Bxyci'},
#       'href': 'https://api.spotify.com/v1/artists/69xcFpmqTOmFNOL08Bxyci',
#       'id': '69xcFpmqTOmFNOL08Bxyci',
#       'name': 'Talha Anjum',
#       'type': 'artist',
#       'uri': 'spotify:artist:69xcFpmqTOmFNOL08Bxyci'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1n6pjRJkTY5v8RtUCAv5pi'},
#       'href': 'https://api.spotify.com/v1/artists/1n6pjRJkTY5v8RtUCAv5pi',
#       'id': '1n6pjRJkTY5v8RtUCAv5pi',
#       'name': 'Umair',
#       'type': 'artist',
#       'uri': 'spotify:artist:1n6pjRJkTY5v8RtUCAv5pi'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3hnNOGxe4q5BgwBrG6DWcB'},
#     'href': 'https://api.spotify.com/v1/albums/3hnNOGxe4q5BgwBrG6DWcB',
#     'id': '3hnNOGxe4q5BgwBrG6DWcB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b9ae1b87e013ad747b189687',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b9ae1b87e013ad747b189687',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b9ae1b87e013ad747b189687',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Agency',
#     'release_date': '2021-05-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3hnNOGxe4q5BgwBrG6DWcB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Op1QmEE3Eye8gdNrla3ok'},
#      'href': 'https://api.spotify.com/v1/artists/5Op1QmEE3Eye8gdNrla3ok',
#      'id': '5Op1QmEE3Eye8gdNrla3ok',
#      'name': 'Rap Demon',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Op1QmEE3Eye8gdNrla3ok'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/69xcFpmqTOmFNOL08Bxyci'},
#      'href': 'https://api.spotify.com/v1/artists/69xcFpmqTOmFNOL08Bxyci',
#      'id': '69xcFpmqTOmFNOL08Bxyci',
#      'name': 'Talha Anjum',
#      'type': 'artist',
#      'uri': 'spotify:artist:69xcFpmqTOmFNOL08Bxyci'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1n6pjRJkTY5v8RtUCAv5pi'},
#      'href': 'https://api.spotify.com/v1/artists/1n6pjRJkTY5v8RtUCAv5pi',
#      'id': '1n6pjRJkTY5v8RtUCAv5pi',
#      'name': 'Umair',
#      'type': 'artist',
#      'uri': 'spotify:artist:1n6pjRJkTY5v8RtUCAv5pi'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 271698,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZHN82193817'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1NqWLcX9iImJRQUSXzmkrL'},
#    'href': 'https://api.spotify.com/v1/tracks/1NqWLcX9iImJRQUSXzmkrL',
#    'id': '1NqWLcX9iImJRQUSXzmkrL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Agency',
#    'popularity': 50,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1NqWLcX9iImJRQUSXzmkrL'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yY2gUcIsjMr8hjo51PoJ8'},
#       'href': 'https://api.spotify.com/v1/artists/3yY2gUcIsjMr8hjo51PoJ8',
#       'id': '3yY2gUcIsjMr8hjo51PoJ8',
#       'name': 'The Smiths',
#       'type': 'artist',
#       'uri': 'spotify:artist:3yY2gUcIsjMr8hjo51PoJ8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Y0p2XCgRRIjna91aQE8q7'},
#     'href': 'https://api.spotify.com/v1/albums/5Y0p2XCgRRIjna91aQE8q7',
#     'id': '5Y0p2XCgRRIjna91aQE8q7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ada101c2e9e97feb8fae37a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ada101c2e9e97feb8fae37a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ada101c2e9e97feb8fae37a9',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'The Queen Is Dead',
#     'release_date': '1986-06-16',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5Y0p2XCgRRIjna91aQE8q7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3yY2gUcIsjMr8hjo51PoJ8'},
#      'href': 'https://api.spotify.com/v1/artists/3yY2gUcIsjMr8hjo51PoJ8',
#      'id': '3yY2gUcIsjMr8hjo51PoJ8',
#      'name': 'The Smiths',
#      'type': 'artist',
#      'uri': 'spotify:artist:3yY2gUcIsjMr8hjo51PoJ8'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 244586,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCRL1100054'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0WQiDwKJclirSYG9v5tayI'},
#    'href': 'https://api.spotify.com/v1/tracks/0WQiDwKJclirSYG9v5tayI',
#    'id': '0WQiDwKJclirSYG9v5tayI',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'There Is a Light That Never Goes Out - 2011 Remaster',
#    'popularity': 84,
#    'preview_url': None,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:0WQiDwKJclirSYG9v5tayI'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6n3kcf0OFqgZSbwEoelfEI'},
#       'href': 'https://api.spotify.com/v1/artists/6n3kcf0OFqgZSbwEoelfEI',
#       'id': '6n3kcf0OFqgZSbwEoelfEI',
#       'name': 'aryy',
#       'type': 'artist',
#       'uri': 'spotify:artist:6n3kcf0OFqgZSbwEoelfEI'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1sauqWugPAHkwYw3gvY5ki'},
#     'href': 'https://api.spotify.com/v1/albums/1sauqWugPAHkwYw3gvY5ki',
#     'id': '1sauqWugPAHkwYw3gvY5ki',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738abafb8a0827f1e7c32ee3b8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028abafb8a0827f1e7c32ee3b8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518abafb8a0827f1e7c32ee3b8',
#       'width': 64}],
#     'is_playable': True,
#     'name': "i've grown out of you",
#     'release_date': '2020-08-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1sauqWugPAHkwYw3gvY5ki'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6n3kcf0OFqgZSbwEoelfEI'},
#      'href': 'https://api.spotify.com/v1/artists/6n3kcf0OFqgZSbwEoelfEI',
#      'id': '6n3kcf0OFqgZSbwEoelfEI',
#      'name': 'aryy',
#      'type': 'artist',
#      'uri': 'spotify:artist:6n3kcf0OFqgZSbwEoelfEI'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CG',
#     'TJ',
#     'VE',
#     'ET'],
#    'disc_number': 1,
#    'duration_ms': 166971,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCAEZ2030991'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/027Y8huffOD5CqCbyVlBN5'},
#    'href': 'https://api.spotify.com/v1/tracks/027Y8huffOD5CqCbyVlBN5',
#    'id': '027Y8huffOD5CqCbyVlBN5',
#    'is_local': False,
#    'is_playable': True,
#    'name': "i've grown out of you",
#    'popularity': 17,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:027Y8huffOD5CqCbyVlBN5'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#       'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#       'id': '2vnB6tuQMaQpORiRdvXF9H',
#       'name': 'Beach Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/08jELZMYlptbxXdmLGnFfo'},
#     'href': 'https://api.spotify.com/v1/albums/08jELZMYlptbxXdmLGnFfo',
#     'id': '08jELZMYlptbxXdmLGnFfo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6f804fb1092a0a052aec3a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6f804fb1092a0a052aec3a6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6f804fb1092a0a052aec3a6',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Prom Queen',
#     'release_date': '2018-08-10',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:08jELZMYlptbxXdmLGnFfo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#      'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#      'id': '2vnB6tuQMaQpORiRdvXF9H',
#      'name': 'Beach Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 136562,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZDA71885746'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GJdFTOm23lC5bqjYSMJTj'},
#    'href': 'https://api.spotify.com/v1/tracks/6GJdFTOm23lC5bqjYSMJTj',
#    'id': '6GJdFTOm23lC5bqjYSMJTj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Prom Queen',
#    'popularity': 79,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6GJdFTOm23lC5bqjYSMJTj'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#     'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#     'id': '7aJuG4TFXa2hmE4z1yxc3n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'HIT ME HARD AND SOFT',
#     'release_date': '2024-05-17',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 210373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72401994'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#    'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#    'id': '6dOtVTDdiauQNBQEDOtlAB',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'BIRDS OF A FEATHER',
#    'popularity': 95,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4qZBW3f2Q8y0k1A84d4iAO'},
#     'href': 'https://api.spotify.com/v1/albums/4qZBW3f2Q8y0k1A84d4iAO',
#     'id': '4qZBW3f2Q8y0k1A84d4iAO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731f6a2a40bb692936879db730',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021f6a2a40bb692936879db730',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511f6a2a40bb692936879db730',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'My Dear Melancholy,',
#     'release_date': '2018-03-30',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:4qZBW3f2Q8y0k1A84d4iAO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 228373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG11800560'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN'},
#    'href': 'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#    'id': '09mEdoA6zrmBPgTEN5qXmN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Call Out My Name',
#    'popularity': 86,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:09mEdoA6zrmBPgTEN5qXmN'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ozYqVCLohfpXIhalkhM8D'},
#       'href': 'https://api.spotify.com/v1/artists/3ozYqVCLohfpXIhalkhM8D',
#       'id': '3ozYqVCLohfpXIhalkhM8D',
#       'name': 'Aditya Rikhari',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ozYqVCLohfpXIhalkhM8D'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2xfAmgKBQroCYbDnl18me3'},
#     'href': 'https://api.spotify.com/v1/albums/2xfAmgKBQroCYbDnl18me3',
#     'id': '2xfAmgKBQroCYbDnl18me3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f20ec84c83625511df6a4af5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f20ec84c83625511df6a4af5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f20ec84c83625511df6a4af5',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Faasle',
#     'release_date': '2021-07-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2xfAmgKBQroCYbDnl18me3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ozYqVCLohfpXIhalkhM8D'},
#      'href': 'https://api.spotify.com/v1/artists/3ozYqVCLohfpXIhalkhM8D',
#      'id': '3ozYqVCLohfpXIhalkhM8D',
#      'name': 'Aditya Rikhari',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ozYqVCLohfpXIhalkhM8D'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 221988,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRX282191255'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0s76ExpXyMGVBlKLUr683e'},
#    'href': 'https://api.spotify.com/v1/tracks/0s76ExpXyMGVBlKLUr683e',
#    'id': '0s76ExpXyMGVBlKLUr683e',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Faasle',
#    'popularity': 70,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0s76ExpXyMGVBlKLUr683e'}],
#  'total': 127,
#  'limit': 10,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?offset=0&limit=10&time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?offset=10&limit=10&time_range=short_term',
#  'previous': None}

# %%
def get_track_ids(time_frame):
    track_ids =[]
    for songs in time_frame['items']:
        track_ids.append(songs['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['7qjZnBKE73H4Oxkopwulqe',
#  '3WLJ7D5kh44K5eJ1NqZQ6W',
#  '1CVqr5LImdmJ1Upt4z08Pm',
#  '1NqWLcX9iImJRQUSXzmkrL',
#  '0WQiDwKJclirSYG9v5tayI',
#  '027Y8huffOD5CqCbyVlBN5',
#  '6GJdFTOm23lC5bqjYSMJTj',
#  '6dOtVTDdiauQNBQEDOtlAB',
#  '09mEdoA6zrmBPgTEN5qXmN',
#  '0s76ExpXyMGVBlKLUr683e']

# %%
track_id = '09mEdoA6zrmBPgTEN5qXmN'

# %%
def get_features(id):
    meta = sp.track(id)
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name,album,artist,spotify_url,album_cover]
    return track_info

# %%
features = get_features(track_id)

# %%
features
# Out:
# ['Call Out My Name',
#  'My Dear Melancholy,',
#  'The Weeknd',
#  'https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN',
#  'https://i.scdn.co/image/ab67616d0000b2731f6a2a40bb692936879db730']

# %%
tracks = []
for i in track_ids:
    time.sleep(0.5)
    track = get_features(i)
    tracks.append(track)

# %%
tracks
# Out:
# [['back to friends',
#   'I Barely Know Her',
#   'sombr',
#   'https://open.spotify.com/track/7qjZnBKE73H4Oxkopwulqe',
#   'https://i.scdn.co/image/ab67616d0000b273d2eb391e0b3c3bc21c127db6'],
#  ['Baarishein',
#   'Baarishein',
#   'Anuv Jain',
#   'https://open.spotify.com/track/3WLJ7D5kh44K5eJ1NqZQ6W',
#   'https://i.scdn.co/image/ab67616d0000b273d8ca783fa570b57e082f4374'],
#  ['Tu Hi Mera',
#   'Jannat 2 (Original Motion Picture Soundtrack)',
#   'Pritam',
#   'https://open.spotify.com/track/1CVqr5LImdmJ1Upt4z08Pm',
#   'https://i.scdn.co/image/ab67616d0000b27371da5e89467bd75d2ed9f1fa'],
#  ['Agency',
#   'Agency',
#   'Rap Demon',
#   'https://open.spotify.com/track/1NqWLcX9iImJRQUSXzmkrL',
#   'https://i.scdn.co/image/ab67616d0000b273b9ae1b87e013ad747b189687'],
#  ['There Is a Light That Never Goes Out - 2011 Remaster',
#   'The Queen Is Dead',
#   'The Smiths',
#   'https://open.spotify.com/track/0WQiDwKJclirSYG9v5tayI',
#   'https://i.scdn.co/image/ab67616d0000b273ada101c2e9e97feb8fae37a9'],
#  ["i've grown out of you",
#   "i've grown out of you",
#   'aryy',
#   'https://open.spotify.com/track/027Y8huffOD5CqCbyVlBN5',
#   'https://i.scdn.co/image/ab67616d0000b2738abafb8a0827f1e7c32ee3b8'],
#  ['Prom Queen',
#   'Prom Queen',
#   'Beach Bunny',
#   'https://open.spotify.com/track/6GJdFTOm23lC5bqjYSMJTj',
#   'https://i.scdn.co/image/ab67616d0000b273e6f804fb1092a0a052aec3a6'],
#  ['BIRDS OF A FEATHER',
#   'HIT ME HARD AND SOFT',
#   'Billie Eilish',
#   'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62'],
#  ['Call Out My Name',
#   'My Dear Melancholy,',
#   'The Weeknd',
#   'https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN',
#   'https://i.scdn.co/image/ab67616d0000b2731f6a2a40bb692936879db730'],
#  ['Faasle',
#   'Faasle',
#   'Aditya Rikhari',
#   'https://open.spotify.com/track/0s76ExpXyMGVBlKLUr683e',
#   'https://i.scdn.co/image/ab67616d0000b273f20ec84c83625511df6a4af5']]

# %%
df = pd.DataFrame(tracks,columns = ['name','album','artist','spotify_url','album_cover'])

# %%
df
# Out:
#                                                 name  \
# 0                                    back to friends
# 1                                         Baarishein
# 2                                         Tu Hi Mera
# 3                                             Agency
# 4  There Is a Light That Never Goes Out - 2011 Re...
# 5                              i've grown out of you
# 6                                         Prom Queen
# 7                                 BIRDS OF A FEATHER
# 8                                   Call Out My Name
# 9                                             Faasle
#
#                                            album          artist  \
# 0                              I Barely Know Her           sombr
# 1                                     Baarishein       Anuv Jain
# 2  Jannat 2 (Original Motion Picture Soundtrack)          Pritam
# 3                                         Agency       Rap Demon
# 4                              The Queen Is Dead      The Smiths
# 5                          i've grown out of you            aryy
# 6                                     Prom Queen     Beach Bunny
# 7                           HIT ME HARD AND SOFT   Billie Eilish
# 8                            My Dear Melancholy,      The Weeknd
# 9                                         Faasle  Aditya Rikhari
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/7qjZnBKE73H4Oxk...
# 1  https://open.spotify.com/track/3WLJ7D5kh44K5eJ...
# 2  https://open.spotify.com/track/1CVqr5LImdmJ1Up...
# 3  https://open.spotify.com/track/1NqWLcX9iImJRQU...
# 4  https://open.spotify.com/track/0WQiDwKJclirSYG...
# 5  https://open.spotify.com/track/027Y8huffOD5CqC...
# 6  https://open.spotify.com/track/6GJdFTOm23lC5bq...
# 7  https://open.spotify.com/track/6dOtVTDdiauQNBQ...
# 8  https://open.spotify.com/track/09mEdoA6zrmBPgT...
# 9  https://open.spotify.com/track/0s76ExpXyMGVBlK...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b273d2eb39...
# 1  https://i.scdn.co/image/ab67616d0000b273d8ca78...
# 2  https://i.scdn.co/image/ab67616d0000b27371da5e...
# 3  https://i.scdn.co/image/ab67616d0000b273b9ae1b...
# 4  https://i.scdn.co/image/ab67616d0000b273ada101...
# 5  https://i.scdn.co/image/ab67616d0000b2738abafb...
# 6  https://i.scdn.co/image/ab67616d0000b273e6f804...
# 7  https://i.scdn.co/image/ab67616d0000b27371d62e...
# 8  https://i.scdn.co/image/ab67616d0000b2731f6a2a...
# 9  https://i.scdn.co/image/ab67616d0000b273f20ec8...

# %%
pip install gspread
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gspread
#   Downloading gspread-6.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from gspread) (2.40.3)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread)
#   Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from google-auth>=1.12.0->gspread) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from google-auth>=1.12.0->gspread) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from google-auth>=1.12.0->gspread) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth>=1.12.0->gspread) (0.6.1)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajy3\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2025.4.26)
# Downloading gspread-6.2.1-py3-none-any.whl (59 kB)
# Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl (19 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: oauthlib, requests-oauthlib, google-auth-oauthlib, gspread
#
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------------------------------------- 0/4 [oauthlib]
#    ---------- ----------------------------- 1/4 [requests-oauthlib]
#    ---------- ----------------------------- 1/4 [requests-oauthlib]
#    ---------- ----------------------------- 1/4 [requests-oauthlib]
#    ---------- ----------------------------- 1/4 [requests-oauthlib]
#    -------------------- ------------------- 2/4 [google-auth-oauthlib]
#    -------------------- ------------------- 2/4 [google-auth-oauthlib]
#    -------------------- ------------------- 2/4 [google-auth-oauthlib]
#    ------------------------------ --------- 3/4 [gspread]
#    ------------------------------ --------- 3/4 [gspread]
#    ------------------------------ --------- 3/4 [gspread]
#    ---------------------------------------- 4/4 [gspread]
#
# Successfully installed google-auth-oauthlib-1.2.3 gspread-6.2.1 oauthlib-3.3.1 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gspread

# %%
gc = gspread.service_account(filename="wrapify_key.json")

# %%
sh = gc.open("My Spotify Wrapped")

# %%
def insert_to_gsheet(track_ids):
    # loop over track ids 
    tracks = []
    for i in range(len(track_ids)):
        time.sleep(.5)
        track = get_features(track_ids[i])
        tracks.append(track)
    # create dataframe
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
    # insert into google sheet
    gc = gspread.service_account(filename='wrapify_key.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
    track_ids = get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# Done
# Done
# Done
